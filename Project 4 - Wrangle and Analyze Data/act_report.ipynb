# %% [markdown]
# ## Report: act_report

# %% [markdown]
# ## 1.Introduction
# In this report, I will lisr the entire communicates the insights and displays the visualization,
#
# I've been wrangling, analyzing, and visualizing the tweet archive of Twitter user @dog rates, also known as WeRateDogs. WeRateDogs is a Twitter account that rates people's dogs and includes a funny comment about the dog.
#
# ## 2. Visualization and Insights
# `First :` **What is the Common Tweet Sources ?**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The first graph demonstrates that, as of 1932, people's preferred method of communication is through their phones. Next, we have Twitter is most effectively used through Deck with 11.
# The first figure demonstrates that there are noticeable gaps between regularly used, demonstrating that some users prefer to use Twitter on their phones, which is undoubtedly acceptable given that people feel more at ease using anything, including Twitter, on their phones in current society.

# %% [markdown]
# `Second:` **What is the commn dog stage ?**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We can clearly observe a significant gap in the dog stages in the two charts above, where the most common dog stage and one with the largest number is the  pupper with 201 and the lowest dog stage is the floofer,doggo with 1.
# From the pie chart we can see that some tweets do not include dog stage information.
